# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Q1. Read the csv and use approppriate function to find out the number of rows and columns in the dataset.

# %%
df=pd.read_csv('titanic_train.csv')

# %% [markdown]
# So,read_csv is a function to read the csv file in pandas

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# Answer:- So, 891 rows and 12 columns are there in this dataset

# %% [markdown]
# ### Q2. How many people out of the total population survived the disaster.

# %% [markdown]
# As seen above total number of people are 891

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[df['Survived']==1].shape[0]
# Out:
# 342

# %% [markdown]
# Answer:- So, there are 342 people out of total population survived the disaster.

# %% [markdown]
# ### Q3. Can you find out out how females survived and how many males did not survive.

# %%
df[ (df['Sex']=='female') & (df['Survived']==1)  ].shape[0]
# Out:
# 233

# %% [markdown]
# So, 233 females who survived

# %%
df[ (df['Sex']=='male') & (df['Survived']==0)  ].shape[0]
# Out:
# 468

# %% [markdown]
# So, 468 males who didn't survive

# %% [markdown]
# ### Q4. What was the mean age of people on the ship

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %% [markdown]
# Answer:- So, the mean age of people on the ship is 29.69911764705882 .

# %% [markdown]
# ### Q5. How many people on the ship had a string 'Mr' in their names.

# %%
def count_Mr(a):
    if 'Mr.' in a:
        return 1
    else:
        return 0

# %%
df['IsMr']=df['Name'].apply(count_Mr)

# %%
df[df['IsMr']==1].shape[0]
# Out:
# 517

# %% [markdown]
# Or

# %%
count=0
for i in df['Name']:
    if 'Mr.' in i:
        count+=1
print(count)
# Out:
# 517

# %% [markdown]
# So, 517 people having 'Mr.' in their names on the ship

# %% [markdown]
# ### Q6. Is there a correlation between Survived and other columns, specify the columns correlated.

# %%
import seaborn as sns

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# Answer:- Pclass,Age,SibSp,Parch,Fare

# %%
sns.heatmap(df.corr())

# %% [markdown]
# Answer:- Fare,Pclass

# %% [markdown]
# ### Q7. How would you make a dataframe of everyone travelling in passenger class 3 and is of age higher than 28.

# %%
df[ (df['Pclass']==3) & (df['Age']>28)  ]
# Out:
#      PassengerId  Survived  Pclass  \
# 4              5         0       3
# 13            14         0       3
# 18            19         0       3
# 25            26         1       3
# 40            41         0       3
# 57            58         0       3
# 74            75         1       3
# 79            80         1       3
# 81            82         1       3
# 85            86         1       3
# 90            91         0       3
# 94            95         0       3
# 103          104         0       3
# 104          105         0       3
# 108          109         0       3
# 116          117         0       3
# 129          130         0       3
# 130          131         0       3
# 132          133         0       3
# 152          153         0       3
# 153          154         0       3
# 157          158         0       3
# 160          161         0       3
# 167          168         0       3
# 179          180         0       3
# ...

# %% [markdown]
# ###  Q8. What is the mean fare paid by people travelling with passenger class one,two and three.

# %% [markdown]
# Mean Fare by Passenger Class 1

# %%
df[df['Pclass']==1]['Fare'].mean()
# Out:
# 84.15468749999992

# %% [markdown]
# Mean Fare by Passenger Class 2

# %%
df[df['Pclass']==2]['Fare'].mean()
# Out:
# 20.66218315217391

# %% [markdown]
# Mean Fare by Passenger Class 3

# %%
df[df['Pclass']==3]['Fare'].mean()
# Out:
# 13.675550101832997

# %% [markdown]
# ### Q9. Write a function to replace the word male in Sex column by 'M' and the word female by 'F'. Apply this function on the Sex column.

# %%
def changeSexValue(a):
    if a=='male':
        return 'M'
    else:
        return 'F'

# %%
df['Sex']=df['Sex'].apply(changeSexValue)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# ### Q10. Get the values of the age column in a numpy array, now BROADCAST a value 20 on the last 7 elements of the numpy array.

# %%
narr=np.array(df['Age'])

# %%
narr
# Out:
# array([22.  , 38.  , 26.  , 35.  , 35.  ,   nan, 54.  ,  2.  , 27.  ,
#        14.  ,  4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  ,   nan,
#        31.  ,   nan, 35.  , 34.  , 15.  , 28.  ,  8.  , 38.  ,   nan,
#        19.  ,   nan,   nan, 40.  ,   nan,   nan, 66.  , 28.  , 42.  ,
#          nan, 21.  , 18.  , 14.  , 40.  , 27.  ,   nan,  3.  , 19.  ,
#          nan,   nan,   nan,   nan, 18.  ,  7.  , 21.  , 49.  , 29.  ,
#        65.  ,   nan, 21.  , 28.5 ,  5.  , 11.  , 22.  , 38.  , 45.  ,
#         4.  ,   nan,   nan, 29.  , 19.  , 17.  , 26.  , 32.  , 16.  ,
#        21.  , 26.  , 32.  , 25.  ,   nan,   nan,  0.83, 30.  , 22.  ,
#        29.  ,   nan, 28.  , 17.  , 33.  , 16.  ,   nan, 23.  , 24.  ,
#        29.  , 20.  , 46.  , 26.  , 59.  ,   nan, 71.  , 23.  , 34.  ,
#        34.  , 28.  ,   nan, 21.  , 33.  , 37.  , 28.  , 21.  ,   nan,
#        38.  ,   nan, 47.  , 14.5 , 22.  , 20.  , 17.  , 21.  , 70.5 ,
# ...

# %%
narr[-7:]=20

# %%
narr
# Out:
# array([22.  , 38.  , 26.  , 35.  , 35.  ,   nan, 54.  ,  2.  , 27.  ,
#        14.  ,  4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  ,   nan,
#        31.  ,   nan, 35.  , 34.  , 15.  , 28.  ,  8.  , 38.  ,   nan,
#        19.  ,   nan,   nan, 40.  ,   nan,   nan, 66.  , 28.  , 42.  ,
#          nan, 21.  , 18.  , 14.  , 40.  , 27.  ,   nan,  3.  , 19.  ,
#          nan,   nan,   nan,   nan, 18.  ,  7.  , 21.  , 49.  , 29.  ,
#        65.  ,   nan, 21.  , 28.5 ,  5.  , 11.  , 22.  , 38.  , 45.  ,
#         4.  ,   nan,   nan, 29.  , 19.  , 17.  , 26.  , 32.  , 16.  ,
#        21.  , 26.  , 32.  , 25.  ,   nan,   nan,  0.83, 30.  , 22.  ,
#        29.  ,   nan, 28.  , 17.  , 33.  , 16.  ,   nan, 23.  , 24.  ,
#        29.  , 20.  , 46.  , 26.  , 59.  ,   nan, 71.  , 23.  , 34.  ,
#        34.  , 28.  ,   nan, 21.  , 33.  , 37.  , 28.  , 21.  ,   nan,
#        38.  ,   nan, 47.  , 14.5 , 22.  , 20.  , 17.  , 21.  , 70.5 ,
# ...
